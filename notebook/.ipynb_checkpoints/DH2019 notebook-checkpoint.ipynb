# %%
# notebook for settings generation

# %%
import urdubiometer as ubm
from graphtransliterator import GraphTransliterator
urduGT = GraphTransliterator.from_yaml_file("../../transliterate/urdu.yml")
scholarlyGT = GraphTransliterator.from_yaml_file("../../transliterate/transliteration.yml")
hindiGT = GraphTransliterator.from_yaml_file('../../transliterate/devanagari.yaml')

# %%
lines = '''bol kih lab aazaad hai;n tere
bol zabaa;n ab tak terii hai
teraa sutvaa;n jism hai teraa
bol kih jaa;n ab tak terii hai
dekh kih aahangar kii dukaa;n me;n
tund hai;n shole sur;x hai aahan
khulne lage quflo;n ke dahaane
phailaa har ik zanjiir kaa daaman
bol yah tho;raa vaqt bahut hai
jism-o-zabaa;n kii maut se pahle
bol kih sach zindah hai ab tak
bol jo kuchh kahnaa hai kah le'''.split('\n')

lines_en = '''Speak, for your lips are free
Speak, for your tongue is still yours
Your long-suffering body is yours
Speak, for your life is still your own
Speak, for in the blacksmith's shop
The flames are fierce, the iron red
The mouths of locks have begun to open
The skirt of every chain is outspread
Speak, this little time is enough
Before the death of the body and tongue
Speak, for truth is still alive
Speak, say what must be said
'''.split("\n")

lines_ur = [urduGT.transliterate(line) for line in lines]
lines_trans = [scholarlyGT.transliterate(line) for line in lines]
lines_hi = [hindiGT.transliterate(line) for line in lines]

# %%
def vocalize(line):
    def show_arab(token):
        replacements = [ ('a', '^a'),
                         ('i', '^i'),
                         ('u', '^u'),
                         ('ai', '^ai'),
                         ('au', '^au'),
                         ('uu', '^uu')]
        for a, b in replacements:
            if token == a:
                token = b
        return token
    return ''.join([show_arab(token) for token in urduGT.tokenize(line)])

# %%
scanner = ubm.DefaultScanner(meters_list=[{'id':0, 'name': "Faiz", "regex_pattern": "=(=|--)===(=|--)=="}])
# Out:
# /Users/seanpue/MyWorkspace/urdubiometer/urdubiometer/graphparser/graphparser.py:541: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(yaml_str)
# /Users/seanpue/MyWorkspace/urdubiometer/urdubiometer/graphparser/validate.py:105: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """)
# /Users/seanpue/MyWorkspace/urdubiometer/urdubiometer/scanner/default.py:42: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   return yaml.load(f.read())
# /Users/seanpue/MyWorkspace/urdubiometer/urdubiometer/scanner/validate.py:108: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   schema = yaml.load(schema_str)
# /Users/seanpue/MyWorkspace/urdubiometer/urdubiometer/scanner/validate.py:146: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """

# %%
scans = [scanner.scan(line, graph_details=True)[0] for line in lines]

# %%
# Out:
# {'lines': ['bol kih lab aazaad hai;n tere',
#   'bol zabaa;n ab tak terii hai',
#   'teraa sutvaa;n jism hai teraa',
#   'bol kih jaa;n ab tak terii hai',
#   'dekh kih aahangar kii dukaa;n me;n',
#   'tund hai;n shole sur;x hai aahan',
#   'khulne lage quflo;n ke dahaane',
#   'phailaa har ik zanjiir kaa daaman',
#   'bol yah tho;raa vaqt bahut hai',
#   'jism-o-zabaa;n kii maut se pahle',
#   'bol kih sach zindah hai ab tak',
#   'bol jo kuchh kahnaa hai kah le'],
#  'lines_ur': ['بول کہ لب آزاد ہیں تیرے',
#   'بول زباں اب تک تیری ہے',
#   'تیرا ستواں جسم ہے تیرا',
#   'بول کہ جاں اب تک تیری ہے',
#   'دیکھ کہ آہنگر کی دکاں میں',
#   'تند ہیں شولے سرخ ہے آہن',
#   'کھلنے لگے قفلوں کے دہانے',
#   'پھیلا ہر اک زنجیر کا دامن',
#   'بول یہ تھوڑا وقت بہت ہے',
#   'جسم و زباں کی موت سے پہلے',
#   'بول کہ سچ زندہ ہے اب تک',
#   'بول جو کچھ کہنا ہے کہہ لے'],
#  'lines_en': "Speak, for your lips are free\nSpeak, for your tongue is still yours\nYour long-suffering body is yours\nSpeak, for your life is still your own\nSpeak, for in the blacksmith's shop\nThe flames are fierce, the iron red\nThe mouths of locks have begun to open\nThe skirt of every chain is outspread\nSpeak, this little time is enough\nBefore the death of the body and tongue\nSpeak, for truth is still alive\nSpeak, say what must be said\n",
#  'lines_hi': ['बोल कि लब आज़ाद हैं तेरे',
#   'बोल ज़बाँ अब तक तेरी है',
#   'तेरा सुत्वाँ जिस्म है तेरा',
#   'बोल कि जाँ अब तक तेरी है',
#   'देख कि आहंगर की दुकाँ में',
#   'तुंद हैं शोले सुर्ख़ है आहन',
#   'खुलने लगे क़ुफ़्लों के दहाने',
#   'फैला हर इक ज़ंजीर का दामन',
#   'बोल यह थोड़ा वक़त बहुत है',
#   'जिस्म‐ओ‐ज़बाँ की मौत से पहले',
#   'बोल कि सच ज़िंदा है अब तक',
#   'बोल जो कुछ कहना है कह ले'],
#  'scans': {'1': ScanResult(scan='=--===--==', matches=[NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=1, orig_tokens=[' ', 'b', 'o'], rule_found='l_bcv', token_i=0, parent_key=0), NodeMatch(type='-', matched_tokens=['c'], node_key=3, orig_tokens=['l'], rule_found='s_c', token_i=3, parent_key=1), NodeMatch(type='-', matched_tokens=['b', 'nah'], node_key=5, orig_tokens=[' ', 'k', 'i', 'h'], rule_found='s_bnah', token_i=4, parent_key=3), NodeMatch(type='=', matched_tokens=['b', 'c', 's', 'c'], node_key=4, orig_tokens=[' ', 'l', 'a', 'b'], rule_found='l_bcsc', token_i=6, parent_key=5), NodeMatch(type='=', matched_tokens=['b', 'v'], node_key=6, orig_tokens=[' ', 'aa'], rule_found='l_bv', token_i=10, parent_key=4), NodeMatch(type='=', matched_tokens=['c', 'v'], node_key=7, orig_tokens=['z', 'aa'], rule_found='l_cv', token_i=12, parent_key=6), NodeMatch(type='-', matched_tokens=['c'], node_key=9, orig_tokens=['d'], rule_found='s_c', token_i=14, parent_key=7), NodeMatch(type='-', matched_tokens=['b', 'c', 'v', 'n'], node_key=11, orig_tokens=[' ', 'h', 'ai', ';n'], rule_found='s_bcvn<b>', token_i=15, parent_key=9), NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=10, orig_tokens=[' ', 't', 'e'], rule_found='l_bcv', token_i=19, parent_key=11), NodeMatch(type='=', matched_tokens=['c', 'v'], node_key=12, orig_tokens=['r', 'e'], rule_found='l_cv', token_i=22, parent_key=10)], meter_key=0),
#   '2': ScanResult(scan='=--======', matches=[NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=1, orig_tokens=[' ', 'b', 'o'], rule_found='l_bcv', token_i=0, parent_key=0), NodeMatch(type='-', matched_tokens=['c'], node_key=3, orig_tokens=['l'], rule_found='s_c', token_i=3, parent_key=1), NodeMatch(type='-', matched_tokens=['b', 'c', 's'], node_key=5, orig_tokens=[' ', 'z', 'a'], rule_found='s_bcs', token_i=4, parent_key=3), NodeMatch(type='=', matched_tokens=['c', 'v', 'n<(aa)wb>'], node_key=4, orig_tokens=['b', 'aa', ';n'], rule_found='l_cvn<(aa)wb>', token_i=7, parent_key=5), NodeMatch(type='=', matched_tokens=['b', 's', 'c'], node_key=6, orig_tokens=[' ', 'a', 'b'], rule_found='l_bsc', token_i=10, parent_key=4), NodeMatch(type='=', matched_tokens=['b', 'c', 's', 'c'], node_key=7, orig_tokens=[' ', 't', 'a', 'k'], rule_found='l_bcsc', token_i=13, parent_key=6), NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=8, orig_tokens=[' ', 't', 'e'], rule_found='l_bcv', token_i=17, parent_key=7), NodeMatch(type='=', matched_tokens=['c', 'v'], node_key=10, orig_tokens=['r', 'ii'], rule_found='l_cv', token_i=20, parent_key=8), NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=12, orig_tokens=[' ', 'h', 'ai'], rule_found='l_bcv', token_i=22, parent_key=10)], meter_key=0),
#   '3': ScanResult(scan='=====--==', matches=[NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=1, orig_tokens=[' ', 't', 'e'], rule_found='l_bcv', token_i=0, parent_key=0), NodeMatch(type='=', matched_tokens=['c', 'v'], node_key=2, orig_tokens=['r', 'aa'], rule_found='l_cv', token_i=3, parent_key=1), NodeMatch(type='=', matched_tokens=['b', 'c', 's', 'c'], node_key=4, orig_tokens=[' ', 's', 'u', 't'], rule_found='l_bcsc', token_i=5, parent_key=2), NodeMatch(type='=', matched_tokens=['c', 'v', 'n<(aa)wb>'], node_key=6, orig_tokens=['v', 'aa', ';n'], rule_found='l_cvn<(aa)wb>', token_i=9, parent_key=4), NodeMatch(type='=', matched_tokens=['b', 'c', 's', 'c'], node_key=7, orig_tokens=[' ', 'j', 'i', 's'], rule_found='l_bcsc', token_i=12, parent_key=6), NodeMatch(type='-', matched_tokens=['c'], node_key=9, orig_tokens=['m'], rule_found='s_c', token_i=16, parent_key=7), NodeMatch(type='-', matched_tokens=['b', 'c', 'v'], node_key=11, orig_tokens=[' ', 'h', 'ai'], rule_found='s_bcv<b>', token_i=17, parent_key=9), NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=10, orig_tokens=[' ', 't', 'e'], rule_found='l_bcv', token_i=20, parent_key=11), NodeMatch(type='=', matched_tokens=['c', 'v'], node_key=12, orig_tokens=['r', 'aa'], rule_found='l_cv', token_i=23, parent_key=10)], meter_key=0),
#   '4': ScanResult(scan='=--======', matches=[NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=1, orig_tokens=[' ', 'b', 'o'], rule_found='l_bcv', token_i=0, parent_key=0), NodeMatch(type='-', matched_tokens=['c'], node_key=3, orig_tokens=['l'], rule_found='s_c', token_i=3, parent_key=1), NodeMatch(type='-', matched_tokens=['b', 'nah'], node_key=5, orig_tokens=[' ', 'k', 'i', 'h'], rule_found='s_bnah', token_i=4, parent_key=3), NodeMatch(type='=', matched_tokens=['b', 'c', 'v', 'n<(aa)wb>'], node_key=4, orig_tokens=[' ', 'j', 'aa', ';n'], rule_found='l_cvn<(aa)wb>', token_i=6, parent_key=5), NodeMatch(type='=', matched_tokens=['b', 's', 'c'], node_key=6, orig_tokens=[' ', 'a', 'b'], rule_found='l_bsc', token_i=10, parent_key=4), NodeMatch(type='=', matched_tokens=['b', 'c', 's', 'c'], node_key=7, orig_tokens=[' ', 't', 'a', 'k'], rule_found='l_bcsc', token_i=13, parent_key=6), NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=8, orig_tokens=[' ', 't', 'e'], rule_found='l_bcv', token_i=17, parent_key=7), NodeMatch(type='=', matched_tokens=['c', 'v'], node_key=10, orig_tokens=['r', 'ii'], rule_found='l_cv', token_i=20, parent_key=8), NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=12, orig_tokens=[' ', 'h', 'ai'], rule_found='l_bcv', token_i=22, parent_key=10)], meter_key=0),
#   '5': ScanResult(scan='=--===--==', matches=[NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=1, orig_tokens=[' ', 'd', 'e'], rule_found='l_bcv', token_i=0, parent_key=0), NodeMatch(type='-', matched_tokens=['c'], node_key=3, orig_tokens=['kh'], rule_found='s_c', token_i=3, parent_key=1), NodeMatch(type='-', matched_tokens=['b', 'nah'], node_key=5, orig_tokens=[' ', 'k', 'i', 'h'], rule_found='s_bnah', token_i=4, parent_key=3), NodeMatch(type='=', matched_tokens=['b', 'v'], node_key=4, orig_tokens=[' ', 'aa'], rule_found='l_bv', token_i=6, parent_key=5), NodeMatch(type='=', matched_tokens=['c', 's', 'c'], node_key=6, orig_tokens=['h', 'a', 'n'], rule_found='l_csc', token_i=8, parent_key=4), NodeMatch(type='=', matched_tokens=['c', 's', 'c'], node_key=7, orig_tokens=['g', 'a', 'r'], rule_found='l_csc', token_i=11, parent_key=6), NodeMatch(type='-', matched_tokens=['b', 'c', 'v'], node_key=9, orig_tokens=[' ', 'k', 'ii'], rule_found='s_bcv<b>', token_i=14, parent_key=7), NodeMatch(type='-', matched_tokens=['b', 'c', 's'], node_key=11, orig_tokens=[' ', 'd', 'u'], rule_found='s_bcs', token_i=17, parent_key=9), NodeMatch(type='=', matched_tokens=['c', 'v', 'n<(aa)wb>'], node_key=10, orig_tokens=['k', 'aa', ';n'], rule_found='l_cvn<(aa)wb>', token_i=20, parent_key=11), NodeMatch(type='=', matched_tokens=['b', 'c', 'v', 'n'], node_key=12, orig_tokens=[' ', 'm', 'e', ';n'], rule_found='l_bcvn', token_i=23, parent_key=10)], meter_key=0),
#   '6': ScanResult(scan='=--===--==', matches=[NodeMatch(type='=', matched_tokens=['b', 'c', 's', 'c'], node_key=1, orig_tokens=[' ', 't', 'u', 'n'], rule_found='l_bcsc', token_i=0, parent_key=0), NodeMatch(type='-', matched_tokens=['c'], node_key=3, orig_tokens=['d'], rule_found='s_c', token_i=4, parent_key=1), NodeMatch(type='-', matched_tokens=['b', 'c', 'v', 'n'], node_key=5, orig_tokens=[' ', 'h', 'ai', ';n'], rule_found='s_bcvn<b>', token_i=5, parent_key=3), NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=4, orig_tokens=[' ', 'sh', 'o'], rule_found='l_bcv', token_i=9, parent_key=5), NodeMatch(type='=', matched_tokens=['c', 'v'], node_key=6, orig_tokens=['l', 'e'], rule_found='l_cv', token_i=12, parent_key=4), NodeMatch(type='=', matched_tokens=['b', 'c', 's', 'c'], node_key=7, orig_tokens=[' ', 's', 'u', 'r'], rule_found='l_bcsc', token_i=14, parent_key=6), NodeMatch(type='-', matched_tokens=['c'], node_key=9, orig_tokens=[';x'], rule_found='s_c', token_i=18, parent_key=7), NodeMatch(type='-', matched_tokens=['b', 'c', 'v'], node_key=11, orig_tokens=[' ', 'h', 'ai'], rule_found='s_bcv<b>', token_i=19, parent_key=9), NodeMatch(type='=', matched_tokens=['b', 'v'], node_key=10, orig_tokens=[' ', 'aa'], rule_found='l_bv', token_i=22, parent_key=11), NodeMatch(type='=', matched_tokens=['c', 's', 'c'], node_key=12, orig_tokens=['h', 'a', 'n'], rule_found='l_csc', token_i=24, parent_key=10)], meter_key=0),
#   '7': ScanResult(scan='=--===--==', matches=[NodeMatch(type='=', matched_tokens=['b', 'c', 's', 'c'], node_key=1, orig_tokens=[' ', 'kh', 'u', 'l'], rule_found='l_bcsc', token_i=0, parent_key=0), NodeMatch(type='-', matched_tokens=['c', 'v'], node_key=3, orig_tokens=['n', 'e'], rule_found='s_cv<b>', token_i=4, parent_key=1), NodeMatch(type='-', matched_tokens=['b', 'c', 's'], node_key=5, orig_tokens=[' ', 'l', 'a'], rule_found='s_bcs', token_i=6, parent_key=3), NodeMatch(type='=', matched_tokens=['c', 'v'], node_key=4, orig_tokens=['g', 'e'], rule_found='l_cv', token_i=9, parent_key=5), NodeMatch(type='=', matched_tokens=['b', 'c', 's', 'c'], node_key=6, orig_tokens=[' ', 'q', 'u', 'f'], rule_found='l_bcsc', token_i=11, parent_key=4), NodeMatch(type='=', matched_tokens=['c', 'v', 'n'], node_key=7, orig_tokens=['l', 'o', ';n'], rule_found='l_cvn', token_i=15, parent_key=6), NodeMatch(type='-', matched_tokens=['b', 'c', 'v'], node_key=9, orig_tokens=[' ', 'k', 'e'], rule_found='s_bcv<b>', token_i=18, parent_key=7), NodeMatch(type='-', matched_tokens=['b', 'c', 's'], node_key=11, orig_tokens=[' ', 'd', 'a'], rule_found='s_bcs', token_i=21, parent_key=9), NodeMatch(type='=', matched_tokens=['c', 'v'], node_key=10, orig_tokens=['h', 'aa'], rule_found='l_cv', token_i=24, parent_key=11), NodeMatch(type='=', matched_tokens=['c', 'v'], node_key=12, orig_tokens=['n', 'e'], rule_found='l_cv', token_i=26, parent_key=10)], meter_key=0),
#   '8': ScanResult(scan='=--===--==', matches=[NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=1, orig_tokens=[' ', 'ph', 'ai'], rule_found='l_bcv', token_i=0, parent_key=0), NodeMatch(type='-', matched_tokens=['c', 'v'], node_key=3, orig_tokens=['l', 'aa'], rule_found='s_cv<b>', token_i=3, parent_key=1), NodeMatch(type='-', matched_tokens=['b', 'c', 's'], node_key=5, orig_tokens=[' ', 'h', 'a'], rule_found='s_bcs', token_i=5, parent_key=3), NodeMatch(type='=', matched_tokens=['c', 'b', 's', 'c'], node_key=4, orig_tokens=['r', ' ', 'i', 'k'], rule_found='l_cbsc', token_i=8, parent_key=5), NodeMatch(type='=', matched_tokens=['b', 'c', 's', 'c'], node_key=6, orig_tokens=[' ', 'z', 'a', 'n'], rule_found='l_bcsc', token_i=12, parent_key=4), NodeMatch(type='=', matched_tokens=['c', 'v'], node_key=7, orig_tokens=['j', 'ii'], rule_found='l_cv', token_i=16, parent_key=6), NodeMatch(type='-', matched_tokens=['c'], node_key=9, orig_tokens=['r'], rule_found='s_c', token_i=18, parent_key=7), NodeMatch(type='-', matched_tokens=['b', 'c', 'v'], node_key=11, orig_tokens=[' ', 'k', 'aa'], rule_found='s_bcv<b>', token_i=19, parent_key=9), NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=10, orig_tokens=[' ', 'd', 'aa'], rule_found='l_bcv', token_i=22, parent_key=11), NodeMatch(type='=', matched_tokens=['c', 's', 'c'], node_key=12, orig_tokens=['m', 'a', 'n'], rule_found='l_csc', token_i=25, parent_key=10)], meter_key=0),
#   '9': ScanResult(scan='=--===--==', matches=[NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=1, orig_tokens=[' ', 'b', 'o'], rule_found='l_bcv', token_i=0, parent_key=0), NodeMatch(type='-', matched_tokens=['c'], node_key=3, orig_tokens=['l'], rule_found='s_c', token_i=3, parent_key=1), NodeMatch(type='-', matched_tokens=['b', 'c', 's', 'c<h+wb>'], node_key=5, orig_tokens=[' ', 'y', 'a', 'h'], rule_found='s_bcsc<h+wb>', token_i=4, parent_key=3), NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=4, orig_tokens=[' ', 'th', 'o'], rule_found='l_bcv', token_i=8, parent_key=5), NodeMatch(type='=', matched_tokens=['c', 'v'], node_key=6, orig_tokens=[';r', 'aa'], rule_found='l_cv', token_i=11, parent_key=4), NodeMatch(type='=', matched_tokens=['b', 'c', 's', 'c'], node_key=7, orig_tokens=[' ', 'v', 'a', 'q'], rule_found='l_bcsc', token_i=13, parent_key=6), NodeMatch(type='-', matched_tokens=['c'], node_key=9, orig_tokens=['t'], rule_found='s_c', token_i=17, parent_key=7), NodeMatch(type='-', matched_tokens=['b', 'c', 's'], node_key=11, orig_tokens=[' ', 'b', 'a'], rule_found='s_bcs', token_i=18, parent_key=9), NodeMatch(type='=', matched_tokens=['c', 's', 'c'], node_key=10, orig_tokens=['h', 'u', 't'], rule_found='l_csc', token_i=21, parent_key=11), NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=12, orig_tokens=[' ', 'h', 'ai'], rule_found='l_bcv', token_i=24, parent_key=10)], meter_key=0),
#   '10': ScanResult(scan='=--===--==', matches=[NodeMatch(type='=', matched_tokens=['b', 'c', 's', 'c'], node_key=1, orig_tokens=[' ', 'j', 'i', 's'], rule_found='l_bcsc', token_i=0, parent_key=0), NodeMatch(type='-', matched_tokens=['c', 'o'], node_key=3, orig_tokens=['m', '-o-'], rule_found='s_co', token_i=4, parent_key=1), NodeMatch(type='-', matched_tokens=['c', 's'], node_key=5, orig_tokens=['z', 'a'], rule_found='s_cs', token_i=6, parent_key=3), NodeMatch(type='=', matched_tokens=['c', 'v', 'n<(aa)wb>'], node_key=4, orig_tokens=['b', 'aa', ';n'], rule_found='l_cvn<(aa)wb>', token_i=8, parent_key=5), NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=6, orig_tokens=[' ', 'k', 'ii'], rule_found='l_bcv', token_i=11, parent_key=4), NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=7, orig_tokens=[' ', 'm', 'au'], rule_found='l_bcv', token_i=14, parent_key=6), NodeMatch(type='-', matched_tokens=['c'], node_key=9, orig_tokens=['t'], rule_found='s_c', token_i=17, parent_key=7), NodeMatch(type='-', matched_tokens=['b', 'c', 'v'], node_key=11, orig_tokens=[' ', 's', 'e'], rule_found='s_bcv<b>', token_i=18, parent_key=9), NodeMatch(type='=', matched_tokens=['b', 'c', 's', 'c'], node_key=10, orig_tokens=[' ', 'p', 'a', 'h'], rule_found='l_bcsc', token_i=21, parent_key=11), NodeMatch(type='=', matched_tokens=['c', 'v'], node_key=12, orig_tokens=['l', 'e'], rule_found='l_cv', token_i=25, parent_key=10)], meter_key=0),
#   '11': ScanResult(scan='=--======', matches=[NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=1, orig_tokens=[' ', 'b', 'o'], rule_found='l_bcv', token_i=0, parent_key=0), NodeMatch(type='-', matched_tokens=['c'], node_key=3, orig_tokens=['l'], rule_found='s_c', token_i=3, parent_key=1), NodeMatch(type='-', matched_tokens=['b', 'nah'], node_key=5, orig_tokens=[' ', 'k', 'i', 'h'], rule_found='s_bnah', token_i=4, parent_key=3), NodeMatch(type='=', matched_tokens=['b', 'c', 's', 'c'], node_key=4, orig_tokens=[' ', 's', 'a', 'ch'], rule_found='l_bcsc', token_i=6, parent_key=5), NodeMatch(type='=', matched_tokens=['b', 'c', 's', 'c'], node_key=6, orig_tokens=[' ', 'z', 'i', 'n'], rule_found='l_bcsc', token_i=10, parent_key=4), NodeMatch(type='=', matched_tokens=['c', 's', 'c<h+wb>'], node_key=7, orig_tokens=['d', 'a', 'h'], rule_found='l_csc<h+wb>', token_i=14, parent_key=6), NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=8, orig_tokens=[' ', 'h', 'ai'], rule_found='l_bcv', token_i=17, parent_key=7), NodeMatch(type='=', matched_tokens=['b', 's', 'c'], node_key=10, orig_tokens=[' ', 'a', 'b'], rule_found='l_bsc', token_i=20, parent_key=8), NodeMatch(type='=', matched_tokens=['b', 'c', 's', 'c'], node_key=12, orig_tokens=[' ', 't', 'a', 'k'], rule_found='l_bcsc', token_i=23, parent_key=10)], meter_key=0),
#   '12': ScanResult(scan='=--======', matches=[NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=1, orig_tokens=[' ', 'b', 'o'], rule_found='l_bcv', token_i=0, parent_key=0), NodeMatch(type='-', matched_tokens=['c'], node_key=3, orig_tokens=['l'], rule_found='s_c', token_i=3, parent_key=1), NodeMatch(type='-', matched_tokens=['b', 'c', 'v'], node_key=5, orig_tokens=[' ', 'j', 'o'], rule_found='s_bcv<b>', token_i=4, parent_key=3), NodeMatch(type='=', matched_tokens=['b', 'c', 's', 'c'], node_key=4, orig_tokens=[' ', 'k', 'u', 'chh'], rule_found='l_bcsc', token_i=7, parent_key=5), NodeMatch(type='=', matched_tokens=['b', 'c', 's', 'c'], node_key=6, orig_tokens=[' ', 'k', 'a', 'h'], rule_found='l_bcsc', token_i=11, parent_key=4), NodeMatch(type='=', matched_tokens=['c', 'v'], node_key=7, orig_tokens=['n', 'aa'], rule_found='l_cv', token_i=15, parent_key=6), NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=8, orig_tokens=[' ', 'h', 'ai'], rule_found='l_bcv', token_i=17, parent_key=7), NodeMatch(type='=', matched_tokens=['b', 'c', 's', 'c<h+wb>'], node_key=10, orig_tokens=[' ', 'k', 'a', 'h'], rule_found='l_bcsc<h+wb>', token_i=20, parent_key=8), NodeMatch(type='=', matched_tokens=['b', 'c', 'v'], node_key=12, orig_tokens=[' ', 'l', 'e'], rule_found='l_bcv', token_i=24, parent_key=10)], meter_key=0)}}

# %%
labels_of = {} # "1" -> verse 1

for scan_id, scan in enumerate(scans):
    labels = {'orig': [], 'en': [], 'ur': [], 'hi': []}
    for match in scan.matches:
        orig_tokens = ''.join(match.orig_tokens)
        labels['orig'].append(orig_tokens)
        labels['en'].append(scholarlyGT.transliterate(orig_tokens).replace(" ", "·"))
        labels['ur'].append(urduGT.transliterate(orig_tokens).replace(" ", "·"))
        labels['hi'].append(hindiGT.transliterate(orig_tokens).replace(" ", "·")   )
        
    labels_of[scan_id+1] = labels

# %%
settings = {
    'lines': lines,
    'lines_ur': lines_ur,
    'lines_en': lines_en,
    'lines_hi': lines_hi,
    'scans': {str(i+1):scan for i, scan in enumerate(scans)},
    'labels_of': labels_of
}

import json
with open("../settings.js", "w") as f:
    f.write("settings="+json.dumps(settings))
settings['labels_of']
# Out:
# {1: {'orig': [' bo',
#    'l',
#    ' kih',
#    ' lab',
#    ' aa',
#    'zaa',
#    'd',
#    ' hai;n',
#    ' te',
#    're'],
#   'en': ['·bo', 'l', '·kih', '·lab', '·ā', 'zā', 'd', '·haiñ', '·te', 're'],
#   'ur': ['·بو', 'ل', '·کہ', '·لب', '·آ', 'زا', 'د', '·ہیں', '·تے', 'رے'],
#   'hi': ['·बो', 'ल', '·कि', '·लब', '·आ', 'ज़ा', 'द', '·हैं', '·ते', 'रे']},
#  2: {'orig': [' bo', 'l', ' za', 'baa;n', ' ab', ' tak', ' te', 'rii', ' hai'],
#   'en': ['·bo', 'l', '·za', 'bāñ', '·ab', '·tak', '·te', 'rī', '·hai'],
#   'ur': ['·بو', 'ل', '·ز', 'باں', '·اب', '·تک', '·تے', 'ری', '·ہے'],
#   'hi': ['·बो', 'ल', '·ज़', 'बाँ', '·अब', '·तक', '·ते', 'री', '·है']},
#  3: {'orig': [' te',
#    'raa',
#    ' sut',
#    'vaa;n',
#    ' jis',
#    'm',
#    ' hai',
#    ' te',
#    'raa'],
#   'en': ['·te', 'rā', '·sut', 'vāñ', '·jis', 'm', '·hai', '·te', 'rā'],
#   'ur': ['·تے', 'را', '·ست', 'واں', '·جس', 'م', '·ہے', '·تے', 'را'],
#   'hi': ['·ते', 'रा', '·सुत', 'वाँ', '·जिस', 'म', '·है', '·ते', 'रा']},
#  4: {'orig': [' bo',
#    'l',
#    ' kih',
#    ' jaa;n',
#    ' ab',
#    ' tak',
#    ' te',
#    'rii',
#    ' hai'],
#   'en': ['·bo', 'l', '·kih', '·jāñ', '·ab', '·tak', '·te', 'rī', '·hai'],
#   'ur': ['·بو', 'ل', '·کہ', '·جاں', '·اب', '·تک', '·تے', 'ری', '·ہے'],
#   'hi': ['·बो', 'ल', '·कि', '·जाँ', '·अब', '·तक', '·ते', 'री', '·है']},
#  5: {'orig': [' de',
#    'kh',
#    ' kih',
#    ' aa',
#    'han',
#    'gar',
#    ' kii',
#    ' du',
#    'kaa;n',
#    ' me;n'],
#   'en': ['·de', 'kh', '·kih', '·ā', 'han', 'gar', '·kī', '·du', 'kāñ', '·meñ'],
#   'ur': ['·دے', 'کھ', '·کہ', '·آ', 'ہن', 'گر', '·کی', '·د', 'کاں', '·میں'],
#   'hi': ['·दे', 'ख', '·कि', '·आ', 'हन', 'गर', '·की', '·दु', 'काँ', '·में']},
#  6: {'orig': [' tun',
#    'd',
#    ' hai;n',
#    ' sho',
#    'le',
#    ' sur',
#    ';x',
#    ' hai',
#    ' aa',
#    'han'],
#   'en': ['·tun',
#    'd',
#    '·haiñ',
#    '·sho',
#    'le',
#    '·sur',
#    'ḳh',
#    '·hai',
#    '·ā',
#    'han'],
#   'ur': ['·تن', 'د', '·ہیں', '·شو', 'لے', '·سر', 'خ', '·ہے', '·آ', 'ہن'],
#   'hi': ['·तुन', 'द', '·हैं', '·शो', 'ले', '·सुर', 'ख़', '·है', '·आ', 'हन']},
#  7: {'orig': [' khul',
#    'ne',
#    ' la',
#    'ge',
#    ' quf',
#    'lo;n',
#    ' ke',
#    ' da',
#    'haa',
#    'ne'],
#   'en': ['·khul', 'ne', '·la', 'ge', '·quf', 'loñ', '·ke', '·da', 'hā', 'ne'],
#   'ur': ['·کھل', 'نے', '·ل', 'گے', '·قف', 'لوں', '·کے', '·د', 'ہا', 'نے'],
#   'hi': ['·खुल', 'ने', '·ल', 'गे', '·क़ुफ़', 'लों', '·के', '·द', 'हा', 'ने']},
#  8: {'orig': [' phai',
#    'laa',
#    ' ha',
#    'r ik',
#    ' zan',
#    'jii',
#    'r',
#    ' kaa',
#    ' daa',
#    'man'],
#   'en': ['·phai', 'lā', '·ha', 'r·ik', '·zan', 'jī', 'r', '·kā', '·dā', 'man'],
#   'ur': ['·پھے', 'لا', '·ہ', 'ر·اک', '·زن', 'جی', 'ر', '·کا', '·دا', 'من'],
#   'hi': ['·फै', 'ला', '·ह', 'र·इक', '·ज़न', 'जी', 'र', '·का', '·दा', 'मन']},
#  9: {'orig': [' bo',
#    'l',
#    ' yah',
#    ' tho',
#    ';raa',
#    ' vaq',
#    't',
#    ' ba',
#    'hut',
#    ' hai'],
#   'en': ['·bo', 'l', '·yah', '·tho', 'ṛā', '·vaq', 't', '·ba', 'hut', '·hai'],
#   'ur': ['·بو', 'ل', '·یہ', '·تھو', 'ڑا', '·وق', 'ت', '·ب', 'ہت', '·ہے'],
#   'hi': ['·बो', 'ल', '·यह', '·थो', 'ड़ा', '·वक़', 'त', '·ब', 'हुत', '·है']},
#  10: {'orig': [' jis',
#    'm-o-',
#    'za',
#    'baa;n',
#    ' kii',
#    ' mau',
#    't',
#    ' se',
#    ' pah',
#    'le'],
#   'en': ['·jis', 'm-o-', 'za', 'bāñ', '·kī', '·mau', 't', '·se', '·pah', 'le'],
#   'ur': ['·جس', 'م·و·', 'ز', 'باں', '·کی', '·مو', 'ت', '·سے', '·پہ', 'لے'],
#   'hi': ['·जिस', 'म‐ओ‐', 'ज़', 'बाँ', '·की', '·मौ', 'त', '·से', '·पे', 'ले']},
#  11: {'orig': [' bo',
#    'l',
#    ' kih',
#    ' sach',
#    ' zin',
#    'dah',
#    ' hai',
#    ' ab',
#    ' tak'],
#   'en': ['·bo', 'l', '·kih', '·sach', '·zin', 'dah', '·hai', '·ab', '·tak'],
#   'ur': ['·بو', 'ل', '·کہ', '·سچ', '·زن', 'دہ', '·ہے', '·اب', '·تک'],
#   'hi': ['·बो', 'ल', '·कि', '·सच', '·ज़िन', 'दह', '·है', '·अब', '·तक']},
#  12: {'orig': [' bo',
#    'l',
#    ' jo',
#    ' kuchh',
#    ' kah',
#    'naa',
#    ' hai',
#    ' kah',
#    ' le'],
#   'en': ['·bo', 'l', '·jo', '·kuchh', '·kah', 'nā', '·hai', '·kah', '·le'],
#   'ur': ['·بو', 'ل', '·جو', '·کچھ', '·کہہ', 'نا', '·ہے', '·کہہ', '·لے'],
#   'hi': ['·बो', 'ल', '·जो', '·कुछ', '·कह', 'ना', '·है', '·कह', '·ले']}}
